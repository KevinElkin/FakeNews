# %%
from bs4 import BeautifulSoup
import urllib.request,sys,time
import requests
import pandas as pd
import re
from collections import defaultdict
import seaborn as sns

# %%
fulldf = pd.read_csv('politifact_data.csv')
topSources = fulldf['Source'].value_counts().head(15)
topSourcesdf = topSources.to_frame().reset_index()
topSourcesdf.rename(columns={'Source':'Count'}, inplace=True)
topSourcesdf.rename(columns={'index':'Source'}, inplace=True)
topSourcesdf
# Out:
#              Source  Count
# 0      Donald Trump    823
# 1    Facebook posts    747
# 2          Bloggers    567
# 3      Barack Obama    541
# 4       Viral image    433
# 5   Hillary Clinton    227
# 6      Scott Walker    205
# 7    Bernie Sanders    169
# 8        Rick Perry    168
# 9       Mitt Romney    166
# 10       Rick Scott    165
# 11      Marco Rubio    160
# 12      Chain email    151
# 13         Ted Cruz    139
# 14      John McCain    135

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(15, 13))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="Count", y="Source", data=topSourcesdf,
            label="Total")

# %%
fulldf.groupby('Label').count()
# Out:
#              Quote  Source  Date  Post Author  Link
# Label
# barely-true   2830    2830  2830         2829  2830
# false         3672    3672  3672         3669  3672
# full-flop      155     155   155          155   155
# half-flip       70      70    70           70    70
# half-true     3081    3081  3081         3076  3081
# mostly-true   2928    2928  2928         2925  2928
# no-flip         26      26    26           26    26
# pants-fire    2011    2011  2011         2010  2011
# true          2207    2207  2207         2200  2207

# %%
df.groupby('Label').count()
# Out:
#              Quote  Source  Date  Post Author  Link
# Label
# barely-true   2830    2830  2830         2829  2830
# false         3672    3672  3672         3669  3672
# mostly-true   2928    2928  2928         2925  2928
# pants-fire    2011    2011  2011         2010  2011
# true          2207    2207  2207         2200  2207

# %%
df = df.loc[(df['Label'] != 'full-flop') & (df['Label'] != 'half-flip') & (df['Label'] != 'no-flip')]

# %%
df
# Out:
#                                                    Quote           Source  \
# 0      No U.S. presidents elected before Donald Trump...        Joe Biden
# 1      The CDC said it “made a mistake” and reduced i...      Viral image
# 3      The Trump administration has had “zero unfulfi...     Sean Hannity
# 4      Quotes Tom Brady as saying, “If anyone on my t...           Tweets
# 5      Michigan House “passes bill to ‘voluntarily’ b...   Facebook posts
# ...                                                  ...              ...
# 16972  Democrats' budget resolution would raise Ameri...      John McCain
# 16974  "Hillary (Clinton), one time late at night whe...     Bill Clinton
# 16975  "My husband didn't wrap up the nomination unti...  Hillary Clinton
# 16977  "The Children's Defense Fund rated McCain as t...       MoveOn.org
# 16978  "John McCain voted against establishing a nati...       MoveOn.org
#
#                  Date           Post Author  \
# 0       July 27, 2020        Sophie Austin
# 1       July 27, 2020        Tom Kertscher
# 3       July 27, 2020        Bill McCarthy
# 4       July 27, 2020   Samantha Putterman
# 5       July 27, 2020       Madison Czopek
# ...               ...                   ...
# 16972  April 14, 2008    Adriel Bettelheim
# 16974  April 11, 2008  Angie Drobnic Holan
# 16975   April 9, 2008      Stephanie Garry
# 16977   April 8, 2008  Angie Drobnic Holan
# 16978   April 8, 2008  Angie Drobnic Holan
#
#                                                     Link        Label
# 0      https://www.politifact.com/factchecks/2020/jul...        false
# 1      https://www.politifact.com/factchecks/2020/jul...        false
# 3      https://www.politifact.com/factchecks/2020/jul...        false
# 4      https://www.politifact.com/factchecks/2020/jul...   pants-fire
# 5      https://www.politifact.com/factchecks/2020/jul...  barely-true
# ...                                                  ...          ...
# 16972  https://www.politifact.com/factchecks/2008/apr...        false
# 16974  https://www.politifact.com/factchecks/2008/apr...   pants-fire
# 16975  https://www.politifact.com/factchecks/2008/apr...  barely-true
# 16977  https://www.politifact.com/factchecks/2008/apr...         true
# 16978  https://www.politifact.com/factchecks/2008/apr...         true
#
# [13648 rows x 6 columns]
